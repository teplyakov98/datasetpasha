# %% [markdown]
# # Сбор датасетов из таблиц википедии

# %% [markdown]
# Соберем три различных датасета из англоязычных таблиц википедии:
#
# 1) Коэффициенты УЕФА - https://en.wikipedia.org/wiki/UEFA_coefficient
#
# 2) Список самых продаваемых видеоигр - https://en.wikipedia.org/wiki/List_of_best-selling_video_games
#
# 3) Список языков программирования, возникших с 2010 года - https://en.wikipedia.org/wiki/Timeline_of_programming_languages

# %% [markdown]
# ## Необходимые функции

# %%
import math
import re
import requests

import lxml.html as lh
import numpy as np
import pandas as pd
import seaborn as sns


sns.set()


def get_col_names(col_names):
    """Возвращает список именом столбцов. В таблице может быть 
    заголовок, состоящий из более чем одной строки. В таком случае
    `pandas.read_html()` возвращает заголовок таблицы в формате 
    `pandas.core.index.MultiIndex`, где индексами являются кортежи 
    строк. Данная функция объединяет уникальные элементы таких кортежей 
    в строки через '/'. Например кортеж `('Rank', 'Rank')` заменяется
    строкой `'Rank'`, а кортеж `('Length', 'Electrified')` строкой 
    `'Length/Electrified'`. Если элементом `col_names` является строка,
    то она остается без изменений.
    
    Параметры:
        col_names: последовательность имен столбцов в `pandas.DataFrame`
    
    Возвращает:
        список строк
    
    Исключения:
        ValueError, если элемент `col_names` -- не кортеж и не строка. 
    """
    names = []
    for n in col_names:
        if isinstance(n, tuple):
            sn = ''
            for i, w in enumerate(n):
                if w not in n[:i]:
                    sn += '/' + w
            names.append(sn[1:])
        elif isinstance(n, (str, int)):
            names.append(n)
        else:
            raise ValueError(
                "Unsupported column name type {}\n"
                "Only types `str`, `int` and `Tuple[str]` "
                "are supported.\n"
                "column name: {}".format(type(n), n)
            )
    return names


def remove_excess_info(s):
    """Возвращает строку, полученную из `s` удалением из нее квадратных
    и круглых скобок с их содержимым, а также удалением символа *.
    
    Параметры:
        s: Любой объект. Если не строка, объект возвращается без изменений.
    
    Возвращает:
        строка
    """
    if isinstance(s, str):
        s = re.sub(r'((\[[^\]]*])|(\*)|(~)|(%)|(\([^\)]*\)))', '', s)
        s = re.sub(' +', ' ', s)
        s = s.strip()
    return s

        
def tofloat(x):
    if isinstance(x, str) and x in '—–' \
            or isinstance(x, float) and math.isnan(x):
        return float('nan')
    if isinstance(x, str):
        x = re.sub('[, ]+', '', x)
    try:
        return float(x)
    except ValueError:
        raise ValueError(
            "Cannot convert {} to `float`\nx=={}".format(
                type(x), x))
    


def get_tables_from_html(url):
    """Возвращает список таблиц найденных на веб-странице с адресом `url`.
    
    Параметры:
        url: строка
    
    Возвращает:
        список объектов класса `pandas.DataFrame`
    """
    # Скачиваем веб-страницу
    page = requests.get(url)
    # Преобразуем скачанную страницу в html документ.
    doc = lh.fromstring(page.content.decode('utf-8'))
    # Извлекаем из документа все таблицы
    tables = doc.xpath('//table')
    dfs = []
    for table in tables:
        df = pd.read_html(lh.tostring(table))[0]
        # Следующие 2 строчки кода решают проблему многострочных заголовков
        col_names = get_col_names(df.columns)
        df.columns = col_names
        dfs.append(df)
    return dfs


def prepare_wiki_table(df, int_cols):
    df = df.applymap(remove_excess_info)
    for col in int_cols:
        df[col] = df[col].map(tofloat)
    return df

# %% [markdown]
# ## Коэффициенты УЕФА

# %%
url = "https://en.wikipedia.org/wiki/UEFA_coefficient"
dfs = get_tables_from_html(url)

# %%
len(dfs)
# Out:
# 63

# %%
dfs[10].head()
# Out:
#    Ranking/2020  Ranking/2019 Ranking/Mvmt  \
# 0             1             1            —
# 1             2             2            —
# 2             3             4           +1
# 3             4             3           –1
# 4             5             5            —
#
#   Member association(L: League, C: Cup, LC: League cup1) Coefficient/2015–16  \
# 0                                       Spain (L, C)                  23.928
# 1                                England (L, C, LC1)                  14.250
# 2                                     Germany (L, C)                  16.428
# 3                                       Italy (L, C)                  11.500
# 4                                 France (L, C, LC1)                  11.083
#
#   Coefficient/2016–17  Coefficient/2017–18  Coefficient/2018–19  \
# 0              20.142               19.714               19.571
# 1              14.928               20.071               22.642
# 2              14.571                9.857               15.214
# 3              14.250               17.333               12.642
# 4              14.416               11.500               10.583
#
#    Coefficient/2019–20  Coefficient/Total Teams  Places in 2021–22 season/CL  \
# 0               14.357             97.712   7/7                            4
# 1               14.571             86.462   7/7                            4
# 2               12.428             68.498   6/7                            4
# 3               10.785             66.510   5/7                            4
# 4                8.500             56.082   2/6                            3
#
#    Places in 2021–22 season/EL  Places in 2021–22 season/ECL  \
# 0                            2                             1
# 1                            2                             1
# 2                            2                             1
# 3                            2                             1
# 4                            2                             1
#
#    Places in 2021–22 season/Total
# 0                               7
# 1                               7
# 2                               7
# 3                               7
# 4                               6

# %%
UEFA_coefficient = prepare_wiki_table(dfs[10],['Coefficient/Total'])

# %%
UEFA_coefficient = UEFA_coefficient.rename({'Member association(L: League, C: Cup, LC: League cup1)': 'Country'}, axis=1)

# %%
UEFA_coefficient = UEFA_coefficient.set_index('Country')

# %%
UEFA_coefficient.shape
# Out:
# (55, 14)

# %%
UEFA_coefficient.describe()
# Out:
#        Ranking/2020  Ranking/2019  Coefficient/2017–18  Coefficient/2018–19  \
# count      55.00000      55.00000            55.000000            55.000000
# mean       28.00000      28.00000             4.481782             4.573509
# std        16.02082      16.02082             4.671718             4.598842
# min         1.00000       1.00000             0.000000             0.375000
# 25%        14.50000      14.50000             1.125000             1.500000
# 50%        28.00000      28.00000             2.900000             3.125000
# 75%        41.50000      41.50000             5.562500             5.875000
# max        55.00000      55.00000            20.071000            22.642000
#
#        Coefficient/2019–20  Coefficient/Total  Places in 2021–22 season/CL  \
# count            55.000000          55.000000                    55.000000
# mean              3.966036          21.818800                     1.436364
# std               3.441113          20.959631                     0.897809
# min               0.000000           0.666000                     0.000000
# 25%               1.500000           6.725000                     1.000000
# 50%               3.000000          16.625000                     1.000000
# 75%               4.833000          27.025000                     2.000000
# max              14.571000          97.712000                     4.000000
#
#        Places in 2021–22 season/EL  Places in 2021–22 season/ECL  \
# count                    55.000000                     55.000000
# mean                      0.363636                      3.872727
# std                       0.648749                      4.891620
# min                       0.000000                      1.000000
# 25%                       0.000000                      2.000000
# 50%                       0.000000                      3.000000
# 75%                       1.000000                      3.000000
# max                       2.000000                     23.000000
#
#        Places in 2021–22 season/Total
# count                       55.000000
# mean                         4.309091
# std                          1.086495
# min                          1.000000
# 25%                          4.000000
# 50%                          4.000000
# 75%                          5.000000
# max                          7.000000

# %%
UEFA_coefficient
# Out:
#                         Ranking/2020  Ranking/2019 Ranking/Mvmt  \
# Country
# Spain                              1             1            —
# England                            2             2            —
# Germany                            3             4           +1
# Italy                              4             3           –1
# France                             5             5            —
# Portugal                           6             7           +1
# Russia                             7             6           –1
# Belgium                            8             8            —
# Netherlands                        9            11           +2
# Ukraine                           10             9           –1
# Turkey                            11            10           –1
# Austria                           12            12            —
# Denmark                           13            16           +3
# Czech Republic                    14            13           –1
# Cyprus                            15            18           +3
# Scotland                          16            20           +4
# Greece                            17            14           –3
# Serbia                            18            19           +1
# Croatia                           19            15           –4
# Switzerland                       20            17           –3
# Sweden                            21            22           +1
# Norway                            22            23           +1
# Israel                            23            27           +4
# Kazakhstan                        24            24            —
# Belarus                           25            21           –4
# Azerbaijan                        26            26            —
# Bulgaria                          27            28           +1
# Poland                            28            25           –3
# Romania                           29            29            —
# Slovakia                          30            30            —
# Liechtenstein                     31            32           +1
# Slovenia                          32            31           –1
# Hungary                           33            33            —
# Luxembourg                        34            43           +9
# Lithuania                         35            41           +6
# Armenia                           36            44           +8
# Latvia                            37            42           +5
# Albania                           38            36           –2
# North Macedonia                   39            34           –5
# Bosnia and Herzegovina            40            40            —
# Moldova                           41            35           –6
# Republic of Ireland               42            37           –5
# Finland                           43            38           –5
# Georgia                           44            47           +3
# Malta                             45            45            —
# Iceland                           46            39           –7
# Wales                             47            48           +1
# Northern Ireland                  48            52           +4
# Gibraltar                         49            51           +2
# Montenegro                        50            49           –1
# Estonia                           51            46           –5
# Kosovo                            52            53           +1
# Faroe Islands                     53            50           –3
# Andorra                           54            54            —
# San Marino                        55            55            —
#
#                        Coefficient/2015–16 Coefficient/2016–17  \
# Country
# Spain                               23.928              20.142
# England                             14.250              14.928
# Germany                             16.428              14.571
# Italy                               11.500              14.250
# France                              11.083              14.416
# Portugal                            10.500               8.083
# Russia                              11.500               9.200
# Belgium                              7.400              12.500
# Netherlands                          5.750               9.100
# Ukraine                              9.800               5.500
# Turkey                               6.600               9.700
# Austria                              3.800               7.375
# Denmark                              5.500               8.500
# Czech Republic                       7.300               5.500
# Cyprus                               3.000               5.500
# Scotland                             3.000               4.375
# Greece                               5.400               5.800
# Serbia                               4.250               2.875
# Croatia                              4.500               5.125
# Switzerland                          5.300               4.300
# Sweden                               4.750               2.750
# Norway                               7.250               1.375
# Israel                               2.250               6.750
# Kazakhstan                           4.625               2.750
# Belarus                              5.125               3.000
# Azerbaijan                           4.375               4.250
# Bulgaria                             1.000               4.250
# Poland                               5.500               3.875
# Romania                              2.250               3.300
# Slovakia                             3.750               2.125
# Liechtenstein                        5.000               2.500
# Slovenia                             1.000               2.250
# Hungary                              1.625               1.875
# Luxembourg                           0.750               0.750
# Lithuania                            0.750               0.500
# Armenia                              1.625               1.125
# Latvia                               1.625               1.375
# Albania                              2.125               0.875
# Croatia                               4.375             24.875   0/4
# Switzerland                           4.400             24.400   1/5
# Sweden                                5.750             22.750   1/4
# Norway                                3.750             21.750   0/4
# Israel                                2.375             19.625   0/4
# Kazakhstan                            3.375             19.250   0/4
# Belarus                               2.500             18.875   0/4
# Azerbaijan                            3.375             18.750   0/4
# Bulgaria                              4.125             17.375   1/4
# Poland                                2.125             16.625   0/4
# Romania                               5.375             16.200   1/4
# Slovakia                              3.000             15.875   0/4
# Liechtenstein                         2.500             13.500   0/1
# Slovenia                              2.000             13.000   0/4
# Hungary                               4.500             12.875   0/4
# Luxembourg                            3.000              8.000   0/4
# Lithuania                             1.625              7.875   0/4
# Armenia                               2.750              7.625   0/4
# Latvia                                2.250              7.625   0/4
# Albania                               0.750              7.375   0/4
# North Macedonia                       0.500              7.375   0/4
# Bosnia and Herzegovina                1.500              6.875   0/4
# Moldova                               0.750              6.750   0/4
# Republic of Ireland                   1.250              6.700   0/4
# Finland                               1.625              6.500   0/4
# Georgia                               2.250              5.750   0/4
# Malta                                 0.750              5.750   0/4
# Iceland                               0.625              5.375   0/4
# Wales                                 1.000              5.000   0/4
# Northern Ireland                      2.375              4.875   0/4
# Gibraltar                             1.000              4.750   0/3
# Montenegro                            1.000              4.375   0/4
# Estonia                               0.875              4.375   0/4
# Kosovo                                1.500              4.000   0/2
# Faroe Islands                         1.125              3.750   0/4
# Andorra                               1.500              2.831   0/3
# San Marino                            0.000              0.666   0/3
#
#                         Places in 2021–22 season/CL  \
# Country
# Spain                                             4
# England                                           4
# Germany                                           4
# Italy                                             4
# France                                            3
# Portugal                                          3
# Russia                                            2
# Belgium                                           2
# Netherlands                                       2
# Ukraine                                           2
# Turkey                                            2
# Austria                                           2
# Denmark                                           2
# Czech Republic                                    2
# Cyprus                                            2
# Scotland                                          1
# Greece                                            1
# Serbia                                            1
# Croatia                                           1
# Switzerland                                       1
# Sweden                                            1
# Norway                                            1
# Israel                                            1
# Kazakhstan                                        1
# Belarus                                           1
# Azerbaijan                                        1
# Bulgaria                                          1
# Poland                                            1
# Romania                                           1
# Slovakia                                          1
# Liechtenstein                                     0
# Slovenia                                          1
# Hungary                                           1
# Luxembourg                                        1
# Lithuania                                         1
# Armenia                                           1
# Latvia                                            1
# Albania                                           1
# North Macedonia                                   1
# Bosnia and Herzegovina                            1
# Moldova                                           1
# Republic of Ireland                               1
# Finland                                           1
# Georgia                                           1
# Malta                                             1
# Iceland                                           1
# Wales                                             1
# Northern Ireland                                  1
# Gibraltar                                         1
# Montenegro                                        1
# Estonia                                           1
# Kosovo                                            1
# Faroe Islands                                     1
# Andorra                                           1
# San Marino                                        1
#
#                         Places in 2021–22 season/EL  \
# Country
# Spain                                             2
# England                                           2
# Germany                                           2
# Italy                                             2
# France                                            2
# Portugal                                          1
# Russia                                            1
# Belgium                                           1
# Netherlands                                       1
# Ukraine                                           1
# Turkey                                            1
# Austria                                           1
# Denmark                                           1
# Czech Republic                                    1
# Cyprus                                            1
# Scotland                                          0
# Greece                                            0
# Serbia                                            0
# Croatia                                           0
# Kosovo                                               3
# Faroe Islands                                        3
# Andorra                                              3
# San Marino                                           2

# %% [markdown]
# ## Список самых продаваемых видеоигр

# %%
url = "https://en.wikipedia.org/wiki/List_of_best-selling_video_games"
dfs = get_tables_from_html(url)

# %%
len(dfs)
# Out:
# 4

# %%
dfs[1].head()
# Out:
#                            Title           Sales     Platform(s)  \
# 0                      Minecraft  180,000,000[b]  Multi-platform
# 1                         Tetris  170,000,000[b]  Multi-platform
# 2             Grand Theft Auto V       115000000  Multi-platform
# 3                     Wii Sports        82880000             Wii
# 4  PlayerUnknown's Battlegrounds        50000000  Multi-platform
#
#    Initial release date      Developer(s)[a]    Publisher(s)[a]  \
# 0  November 18, 2011[c]               Mojang  Xbox Game Studios
# 1          June 6, 1984  Elektronorgtechnica         Various[d]
# 2    September 17, 2013       Rockstar North     Rockstar Games
# 3     November 19, 2006         Nintendo EAD           Nintendo
# 4     December 20, 2017     PUBG Corporation   PUBG Corporation
#
#    Bundled with a console?    Ref.
# 0                      NaN     [3]
# 1                      NaN  [5][e]
# 2                      NaN     [9]
# 3                      NaN    [10]
# 4                      NaN    [11]

# %%
VideoGames = prepare_wiki_table(dfs[1],['Sales'])

# %%
VideoGames = VideoGames.set_index('Title')

# %%
VideoGames = VideoGames.drop(['Bundled with a console?','Ref.'],axis=1)

# %%
VideoGames.shape
# Out:
# (51, 5)

# %%
VideoGames.describe()
# Out:
#               Sales
# count  5.100000e+01
# mean   3.441306e+07
# std    3.321759e+07
# min    1.600000e+07
# 25%    2.000000e+07
# 50%    2.473000e+07
# 75%    3.000000e+07
# max    1.800000e+08

# %%
VideoGames
# Out:
#                                                Sales       Platform(s)  \
# Title
# Minecraft                                180000000.0    Multi-platform
# Tetris                                   170000000.0    Multi-platform
# Grand Theft Auto V                       115000000.0    Multi-platform
# Wii Sports                                82880000.0               Wii
# PlayerUnknown's Battlegrounds             50000000.0    Multi-platform
# Super Mario Bros.                         48240000.0    Multi-platform
# Pokémon Red/Green/Blue/Yellow             47520000.0    Multi-platform
# Wii Fit and Wii Fit Plus                  43800000.0               Wii
# Mario Kart Wii                            37240000.0               Wii
# Wii Sports Resort                         33110000.0               Wii
# New Super Mario Bros.                     30800000.0       Nintendo DS
# New Super Mario Bros. Wii                 30280000.0               Wii
# The Elder Scrolls V: Skyrim               30000000.0    Multi-platform
# Diablo III and Reaper of Souls            30000000.0    Multi-platform
# Pokémon Gold/Silver/Crystal               29490000.0    Game Boy Color
# Duck Hunt                                 28300000.0               NES
# Wii Play                                  28020000.0               Wii
# Grand Theft Auto: San Andreas             27500000.0    Multi-platform
# Mario Kart 8/Deluxe                       27450000.0    Multi-platform
# Terraria                                  27000000.0    Multi-platform
# Call of Duty: Modern Warfare 3            26500000.0    Multi-platform
# Red Dead Redemption 2                     26500000.0    Multi-platform
# Call of Duty: Black Ops                   26200000.0    Multi-platform
# Grand Theft Auto IV                       25000000.0    Multi-platform
# Pokémon Sun/Moon/Ultra Sun/Ultra Moon     24740000.0      Nintendo 3DS
# Wii Sports                                                     Nintendo
# PlayerUnknown's Battlegrounds                          PUBG Corporation
# Super Mario Bros.                                              Nintendo
# Pokémon Red/Green/Blue/Yellow                                  Nintendo
# Wii Fit and Wii Fit Plus                                       Nintendo
# Mario Kart Wii                                                 Nintendo
# Wii Sports Resort                                              Nintendo
# New Super Mario Bros.                                          Nintendo
# New Super Mario Bros. Wii                                      Nintendo
# The Elder Scrolls V: Skyrim                          Bethesda Softworks
# Diablo III and Reaper of Souls                   Blizzard Entertainment
# Pokémon Gold/Silver/Crystal                                    Nintendo
# Duck Hunt                                                      Nintendo
# Wii Play                                                       Nintendo
# Grand Theft Auto: San Andreas                            Rockstar Games
# Mario Kart 8/Deluxe                                            Nintendo
# Terraria                                                       Re-Logic
# Call of Duty: Modern Warfare 3                               Activision
# Red Dead Redemption 2                                    Rockstar Games
# Call of Duty: Black Ops                                      Activision
# Grand Theft Auto IV                                      Rockstar Games
# Pokémon Sun/Moon/Ultra Sun/Ultra Moon    Nintendo / The Pokémon Company
# Pokémon Diamond/Pearl/Platinum           Nintendo / The Pokémon Company
# Call of Duty: Black Ops II                                   Activision
# FIFA 18                                                 Electronic Arts
# Kinect Adventures!                                    Xbox Game Studios
# Sonic the Hedgehog                                                 Sega
# Nintendogs                                                     Nintendo
# Mario Kart DS                                                  Nintendo
# Call of Duty: Modern Warfare 2                               Activision
# Pokémon Ruby/Sapphire/Emerald            Nintendo / The Pokémon Company
# Borderlands 2                                                  2K Games
# Super Mario World                                              Nintendo
# Frogger                                                            Sega
# Grand Theft Auto: Vice City                              Rockstar Games
# Lemmings                                                      Psygnosis
# The Witcher 3: Wild Hunt                                     CD Projekt
# Brain Age                                                      Nintendo
# Super Mario Bros. 3                                            Nintendo
# Call of Duty: Ghosts                                         Activision
# Mario Kart 7                                                   Nintendo
# Super Mario Land                                               Nintendo
# Grand Theft Auto III                                     Rockstar Games
# The Last of Us                              Sony Computer Entertainment
# Pokémon X and Y                          Nintendo / The Pokémon Company
# The Legend of Zelda: Breath of the Wild                        Nintendo
# The Sims                                                Electronic Arts
# Need for Speed: Most Wanted                             Electronic Arts

# %% [markdown]
# ## Список языков программирования, возникших с 2010 года

# %%
url = "https://en.wikipedia.org/wiki/Timeline_of_programming_languages"
dfs = get_tables_from_html(url)

# %%
len(dfs)
# Out:
# 13

# %%
dfs[11].head()
# Out:
#    Year    Name Chief developer, company  \
# 0  2010    Rust   Graydon Hoare, Mozilla
# 1  2011     C11    C11 ISO/IEC 9899:2011
# 2  2011  Ceylon      Gavin King, Red Hat
# 3  2011    Dart                   Google
# 4  2011   C++11   C++ ISO/IEC 14882:2011
#
#                                       Predecessor(s)
# 0  Alef, C++, Camlp4, Erlang, Hermes, Limbo, Napi...
# 1                                                NaN
# 2                                               Java
# 3                 Java, JavaScript, CoffeeScript, Go
# 4                                 C++, Standard C, C

# %%
ProgLang = dfs[11]

# %%
ProgLang = ProgLang.query("Name != 'Name'")

# %%
ProgLang = ProgLang.set_index('Name')

# %%
ProgLang.shape
# Out:
# (31, 3)

# %%
ProgLang.describe()
# Out:
#         Year Chief developer, company      Predecessor(s)
# count     31                       30                  25
# unique     9                       30                  23
# top     2011                JetBrains  C++, Standard C, C
# freq       8                        1                   3

# %%
ProgLang
# Out:
#               Year                           Chief developer, company  \
# Name
# Rust          2010                             Graydon Hoare, Mozilla
# C11           2011                              C11 ISO/IEC 9899:2011
# Ceylon        2011                                Gavin King, Red Hat
# Dart          2011                                             Google
# C++11         2011                             C++ ISO/IEC 14882:2011
# Kotlin        2011                                          JetBrains
# Red           2011                                    Nenad Rakocevic
# MonkeyX       2011                                         Mark Sibly
# Opa           2011                                            MLstate
# Elixir        2012                                         José Valim
# Elm           2012                                     Evan Czaplicki
# TypeScript    2012                        Anders Hejlsberg, Microsoft
# Julia         2012  Jeff Bezanson, Stefan Karpinski, Viral Shah, A...
# P             2012  Vivek Gupta, Ethan Jackson, Shaz Qadeer, Srira...
# Ada 2012      2012             ARA and Ada Europe (ISO/IEC 8652:2012)
# P4            2013                    P4 Language Consortium (P4.org)
# Hopscotch     2013                             Hopscotch Technologies
# Cuneiform     2013                                      Jörgen Brandt
# Crystal       2014        Ary Borenszweig, Manas Technology Solutions
# Hack          2014                                           Facebook
# Swift         2014                                         Apple Inc.
# C++14         2014                             C++ ISO/IEC 14882:2014
# MakeCode      2015                                          Microsoft
# Raku          2015                                    The Rakudo Team
# pony          2015                                                NaN
# Reason        2016                                       Jordan Walke
# Ring          2016                                      Mahmoud Fayed
# C++17         2017                             C++ ISO/IEC 14882:2017
# Ballerina     2017                              WSO2, Open Source[14]
# C18           2018                              C18 ISO/IEC 9899:2018
# Fortran 2018  2018                   ISO/IEC JTC1/SC22/WG5 N2150:2018
#
#                                                  Predecessor(s)
# Name
# Rust          Alef, C++, Camlp4, Erlang, Hermes, Limbo, Napi...
# C11                                                         NaN
# Ceylon                                                     Java
# Dart                         Java, JavaScript, CoffeeScript, Go
# C++11                                        C++, Standard C, C
# Kotlin                            Java, Scala, Groovy, C#, Gosu
# Red                                           Rebol, Scala, Lua
# MonkeyX                                                     NaN
# Opa                                   OCaml, Erlang, JavaScript
# Elixir                                    Erlang, Ruby, Clojure
# Elm                             Haskell, Standard ML, OCaml, F#
# TypeScript                             JavaScript, CoffeeScript
# Julia         MATLAB, Lisp, C, Fortran, Mathematica[11] (str...
# P                                                           NaN
# Ada 2012                 Ada 2005, ISO/IEC 8652:1995/Amd 1:2007
# P4                                                          NaN
# Hopscotch                                               Scratch
# Cuneiform                   Swift (parallel scripting language)
# Crystal                           Ruby, C, Rust, Go, C#, Python
# Hack                                                        PHP
# Swift         Objective-C, Rust, Haskell, Ruby, Python, C#, CLU
# C++14                                        C++, Standard C, C
# MakeCode                                             TypeScript
# Raku                                Perl, Haskell, Python, Ruby
# pony                                                        NaN
# Reason                                    JavaScript, OCaml[13]
# Ring          Lua, Python, Ruby, C, C#, BASIC, QML, xBase, S...
# C++17                                        C++, Standard C, C
# Ballerina                        Java, Javascript, Go, Rust, C#
# C18                                                         NaN
# Fortran 2018                                       Fortran 2008
